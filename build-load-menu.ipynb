# %%
from financial_dataset_loader import *

# %%
load_menu_snapshot_s3(menu_code='3233')
# Out:
# 125 Files matching the regex 'menu3233-code000000' in the bucket 'dataset-system' with prefix 'dataset-menu3233/':
# Successfully read file: dataset-menu3233/menu3233-code000000-at20250218-save20250219.csv
# DataFrame shape: (205, 18)
#             기준일    펀드코드                           펀드명         설정일   판매사코드  \
# 순번
# 1    2025-02-18  000005             라이프IPO일반사모투자신탁제2호  2020-08-26  000000
# 2    2025-02-18  000006     라이프IPO일반사모투자신탁제2호 Class C  2020-08-26  000031
# 3    2025-02-18  000012          라이프IPO전문투자형사모투자신탁제3호  2021-02-03  000000
# 4    2025-02-18  000014  라이프IPO전문투자형사모투자신탁제3호 Class C  2021-02-03  000031
# 5    2025-02-18  000018            라이프SPAC일반사모투자신탁제1호  2021-03-25  000000
# ..          ...     ...                           ...         ...     ...
# 201  2025-02-18  A00011                     한국증권금융 일임  2024-04-24  000000
# 202  2025-02-18  A00012                 라이프 주식 SJ 제3호  2024-06-07  KS0014
# ...
